# %%
input_string = 'hello'
new_string = ''

for char in input_string:
    new_string = char + new_string

print(new_string)
# Out:
# olleh

# %%
input_string4 = 'hello'
new_string4 = ''

for x in input_string2:
    new_string4 = x + new_string4

print(new_string4)
# Out:
# olleh

# %%
for ch in 'Hello world!': print(ch)
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d
# !

# %%
input_string5 = 'Hello world!'
for ch in input_string5:
  print(ch)
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d
# !

# %%
input_string5 = 'Hello world!'
new_string5 = ''
new_string6 = ''
for ch in input_string5:
  print(ch)
  new_string5 = ch + new_string5
  new_string6 = new_string6 + ch
print(new_string5)
print(new_string6)
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d
# !
# !dlrow olleH
# Hello world!
