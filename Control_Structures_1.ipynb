# %% [markdown]
# # **Check Even or Odd**
#
# # **Instructions**
#
# Read an integer and print whether it is even or odd.
#
#
#
# Sample Input:
#
# 4
#
#
#
# # **Sample Output:**
#
# Even

# %%
# Taking input
n = int(input())

# Write your code here
if n % 2 == 0 : result = 'Even'
else :  result = 'Odd'

# Print the output
print(result)
# Out:
# 5
# Odd

# %% [markdown]
# # **Largest of Two Numbers**
#
# # **Instructions**
#
# Read two integers and print the largest one.
#
#
#
# Sample Input:
#
# 3
#
# 7
#
#
#
# # **Sample Output:**
#
# 7

# %%
# Taking input
a = int(input())
b = int(input())

# Write your code here
if a > b : result = a
else : result = b
# Print the output
print(result)
# Out:
# 2
# 3
# 3

# %% [markdown]
# # **Classify Age Group**
#
# # **Instructions**
#
# Write a program to read an age and classify it as Child (<13), Teen (13–17), or Adult (18+). If age is negative, print "Invalid".
#
#
#
#
#
# Sample Input:
#
# 15
#
#
#
# # **Sample Output:**
#
# Teen

# %%
# Taking input
age = int(input())

# Write your code here
if age < 0:
   result = ("Invalid")
elif age < 13:
    result = ("Child")
elif age < 18:
    result = ("Teen")
else:
    result = ("Adult")
# Print the output
print(result)
# Out:
# 5
# Child

# %% [markdown]
# # **Check Triangle Validity**
#
# # **Instructions**
#
# Write a program to compare three sides of a triangle and print whether the triangle is valid or not. A triangle is valid if the sum of two sides is greater than the third side.
#
#
#
#
#
# Sample input 1:
#
# 6.0
#
# 8.2
#
# 10.3
#
#
#
# # **Sample output 1:**
#
# Valid Triangle
#
#
#
#
#
#
#
# Sample input 2:
#
# 5
#
# 9
#
# 15
#
#
#
# Sample output 2:
#
# Invalid Triangle

# %%
# Taking input
a = float(input())
b = float(input())
c = float(input())

# Write your code here
if a + b > c and b + c > a and c + a > b : result = "Valid Triangle"
else : result = "Invalid Triangle"

# Print the output
print(result)
# Out:
# 5
# 9
# 15
# Invalid Triangle

# %% [markdown]
# # **Check for Leap Year**
#
# # **Instructions**
#
# Write a program to determine if a given year is a leap year. A year is a leap year if:
#
#
#
# It is divisible by 4 and not divisible by 100, or
# It is divisible by 400
#
#
#
#
# # **Sample Input 1:**
#
# 2024
#
#
#
# Sample Output 2:
#
# Leap Year
#
#
#
#
#
# Sample Input 1:
#
# 2021
#
#
#
# Sample Output 1:
#
# Not Leap Year

# %%
# Taking input
year = int(input())

# Write your code here
if ( year % 4 == 0 and year % 100 != 0 ) or ( year % 400 == 0 ) : result = "Leap Year"
else : result = "Not Leap Year"
# Print the output
print(result)
# Out:
# 2024
# Leap Year

# %% [markdown]
# **Sum of Even Numbers up to N**
#
# **Instructions**
#
# Write a program to calculate the sum of all even numbers from 1 to N (inclusive).
#
#
#
# Sample Input:
#
# 6
#
#
#
# # **Sample Output:**
#
# 12
#
#
#
# Explanation:
#
# Here, N = 6, hence sum of all even numbers from 1 to 6: 2 + 4 + 6 = 12

# %%
# Taking input
n = int(input())
result = 0
# Write your code here
for i in range(2, n+1, 2): result += i
# Print the output
print(result)
# Out:
# 6
# 12

# %% [markdown]
# # **Count Digits in a Number**
#
# # **Instructions**
#
# Write a program to count the number of digits in a given positive integer N. You need to repeatedly divide the number by 10 and count how many times you can do this before the number becomes zero. This simulates removing the last digit each time.
#
#
#
# If the input number is zero, the count of digits should be 1, since zero itself is a single-digit number.
#
#
#
#
#
# Sample Input 1:
#
# 12345
#
#
#
# # **Sample Output 1:**
#
# 5
#
#
#
#
#
# Sample Input 2:
#
# 0
#
#
#
# Sample Output 2:
#
# 1

# %%
# Taking input
N = int(input())
count = 1
# Write your code here
while N != 0:
    if N // 10 != 0:
        count += 1
    N = N // 10
# Print the output
print(count)
# Out:
# 10010010
# 8

# %% [markdown]
# # **Print Numbers Skipping Multiples of 3**
#
# # **Instructions**
#
# Write a program to print numbers from 1 to n (inclusive), but skip any number that is a multiple of 3.
#
#
#
# Sample Input:
#
# 10
#
#
#
# # **Sample Output:**
#
# 1
#
# 2
#
# 4
#
# 5
#
# 7
#
# 8
#
# 10

# %%
# Taking input
n = int(input())

# Write your code here
for i in range(1,n+1):
    if i % 3 != 0 : print(i)
    else : continue
# Out:
# 10
# 1
# 2
# 4
# 5
# 7
# 8
# 10

# %% [markdown]
# # **Find First Number Divisible by 7**
#
# # **Instructions**
#
# Write a program that reads two integers A and B (with A ≤ B) and finds the first number in the range [A, B] that is divisible by 7.
#
#
#
# If no number in the range is divisible by 7, print 0.
#
#
#
#
#
# Sample Input:
#
# 10
#
# 20
#
#
#
# # **Sample Output:**
#
# 14

# %%
# Taking input
a = int(input())
b = int(input())
result = 0

# Write your code here
for i in range( a , b + 1 ):
    if i % 7 == 0:
        result = i
        break
# Print the output
print(result)
# Out:
# 10
# 20
# 14

# %% [markdown]
# # **Print a Right-Angled Triangle Pattern**
#
# # **Instructions**
#
# Write a program to print a right-angled triangle pattern of stars (*) of height n using nested loops.
#
#
#
# Sample Input:
#
# 4
#
#
#
# # **Sample Output:**
#
# *
#
# **
#
# ***
#
# ****

# %%
# Taking input
n = int(input())

# Write your code here
for i in range( 1 , n + 1 ):
  print("*" * i , end = ' ' )
  print()
# Out:
# 6
# *
# **
# ***
# ****
# *****
# ******

# %% [markdown]
# # **Count Vowels in a String**
#
# # **Instructions**
#
# Write a program to read a string and count the number of vowels in it and print the count.
#
#
#
# Sample Input 1:
#
# Python
#
#
#
# # **Sample Output 1:**
#
# 1
#
#
#
# Sample Input 2:
#
# ProgrAmming
#
#
#
# Sample Output 2:
#
# 3

# %%
# Taking input
s = input()
count = 0
# Write your code here
for ch in s:
    if ch in 'aeiouAEIOU':
        count += 1

print(count)
# Out:
# asdasdSFDSFDSFSDFADAFASFadasdasd
# 8

# %% [markdown]
# # **Electricity Bill Slab Calculator**
#
# # **Instructions**
#
# Electricity bills are calculated based on the number of units (kWh) consumed in a month, with varying rates depending on the consumption slab. Your task is to write a program that computes the total electricity bill amount based on the following tariff structure used by many utility providers:
#
#
#
# For the first 100 units: ₹5 per unit
# For the next 100 units (i.e., from 101 to 200): ₹8 per unit
# For all units beyond 200: ₹10 per unit
#
#
#
#
# The program should take the total number of units consumed in a month as input and compute the total cost accordingly.
#
#
#
#
#
# Sample Input:
#
# 250
#
#
#
# # **Sample Output:**
#
# 1800

# %%
# Taking input
units = int(input())
total_cost = 0
# Write your code here
if units > 200:
    total_cost = ( ( units - 200 ) * 10  ) + ( ( 100 * 8 ) ) + ( ( 100 * 5 ) )
elif units > 100:
    total_cost = ( ( units - 100 ) * 8 ) + ( ( 100 * 5 ) )
else :
    total_cost = ( ( units ) * 5  )

# Print the output
print( total_cost )
# Out:
# 250
# 1800

# %% [markdown]
# # **Elevator Floor Access Control**
#
# # **Instructions**
#
# An elevator controls access based on the floor number and user type. Floors are divided into the following zones:
#
# Floors 1 to 10: Standard access
# Floors 11 to 15: Restricted access
# Floors 16 to 20: VIP access
#
#
# User types and access rights:
#
# "guest": floors 1 to 10 only
# "staff": floors 1 to 15
# "vip": floors 1 to 20
#
#
# Given a floor number and user type, write a program to print "Access Granted" if the user has access to that floor; otherwise print "Access Denied".
#
#
#
# Note: If the floor number is outside 1 to 20, or if the user type is unknown, print "Access Denied".
#
#
#
#
#
# Sample Input 1:
#
# 7
#
# unknown
#
#
#
# # **Sample Output 1:**
#
# Access Denied
#
#
#
# Sample Input 2:
#
# 19
#
# vip
#
#
#
# Sample Output:
#
# Access Granted

# %%
# Taking input
floor = int(input())
user_type = input()
result = "Access Denied"
# Write your code here
if ( floor >= 1 and floor <=20 ) and user_type == "vip" :
    result = "Access Granted"
elif ( floor >= 1 and floor <=15 ) and ( user_type == "vip" or user_type == "staff" ):
    result = "Access Granted"
elif ( floor >= 1 and floor <=10 ) and ( user_type == "vip" or user_type == "staff"  or user_type == "guest" ):
    result = "Access Granted"
else : result = "Access Denied"

# Print the output
print( result )
# Out:
# 21
# vip
# Access Denied

# %% [markdown]
# # **Elevator Direction Display**
#
# # **Instructions**
#
# In a building with floors numbered from 1 to 20, an elevator system needs to decide in which direction it should move based on the current and target floor inputs.
#
#
#
# Based on the values, write a program to:
#
#
#
# Print "Up" if the elevator should go to a higher floor.
# Print "Down" if the elevator should go to a lower floor.
# Print "Stay" if the elevator is already on the target floor.
#
#
# Sample Input:
#
# 5
#
# 8
#
#
#
# # **Sample Output:**
#
# Up

# %%
# Taking input
current = int(input())
target = int(input())
result = "Stay"
# Write your code here
if ( current < target ) : result = "Up"
elif ( current > target ) : result = "Down"
else : result = "Stay"
# Print the output
print( result )
# Out:
# 7
# 7
# Stay

# %% [markdown]
# # **Print Odd Numbers**
#
# # **Instructions**
#
# Given two integers a and b such that a < b, write a program to print all odd numbers between them, not including a or b.
#
#
#
# If there are no odd numbers in the range, print "No odd numbers".
#
#
#
# Sample Input 1:
#
# 3
#
# 10
#
#
#
# # **Sample Output 1:**
#
# 5
#
# 7
#
# 9
#
#
#
# Sample Input 2:
#
# 1
#
# 3
#
#
#
# Sample Output 2:
#
# No odd numbers

# %%
# Taking input
a = int(input())
b = int(input())
count = 0
# Write your code here
for i in range( a+1 , b ):
    if i % 2 != 0 :
        print(i)
        count += 1
if count == 0:
    print("No odd numbers")
# Out:
# 1
# 3
# No odd numbers
