# %% [markdown]
# <a href="https://colab.research.google.com/github/shashwatlko586/AICode586/blob/main/Colab_GH_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os

# 1. Retrieve your secret token
token = userdata.get('GH_Token_586')

# 2. Set your GitHub details
USERNAME = "shashwatlko586"
REPO_NAME = "AICode586"
EMAIL = "shashwat.lko586@gmail.com"

# 3. Configure Git
# !git config --global user.email "{EMAIL}"
# !git config --global user.name "{USERNAME}"

# 4. Clone the repository
# This syntax embeds the token so you don't have to login manually later
repo_url = f"https://{token}@github.com/{USERNAME}/{REPO_NAME}.git"
# !git clone {repo_url}

# 5. Move into the folder
# %cd {REPO_NAME}
# Out:
# Cloning into 'AICode586'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.
# /content/AICode586

# %%
# Check what has changed
# !git status

# Add all changes
# !git add .

# Commit with a message
# !git commit -m "My first commit from Colab"

# Push to GitHub
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
