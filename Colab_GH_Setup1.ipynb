# %%
# Commented out IPython magic to ensure Python compatibility.
# Run only once in 1 session
from google.colab import userdata
import os

# 1. Retrieve your secret token
token = userdata.get('GH_Token_586')

# 2. Set your GitHub details
USERNAME = "shashwatlko586"
REPO_NAME = "AICode586"
EMAIL = "shashwat.lko586@gmail.com"

# 3. Configure Git
# !git config --global user.email "{EMAIL}"
# !git config --global user.name "{USERNAME}"

# 4. Clone the repository
# This syntax embeds the token so you don't have to login manually later
repo_url = f"https://{token}@github.com/{USERNAME}/{REPO_NAME}.git"
# !git clone {repo_url}

# 5. Move into the folder
# %cd {REPO_NAME}

# %%
# Check what has changed
# !git status

# Add all changes
# !git add .

# Commit with a message
# !git commit -m "My first commit from Colab"

# Push to GitHub
# !git push origin main

# %%
import os
from google.colab import userdata

# 1. Configuration
# token = userdata.get('GH_TOKEN') # Use the secret we created earlier
# USERNAME = "your-github-username"
# REPO_NAME = "your-repository-name"

# 2. Define the path in your Drive where you want the project to live
# Change 'MyProjectFolder' to whatever folder name you like
PROJECT_PATH = f"/content/drive/MyDrive/Colab Notebooks/AICode/{REPO_NAME}"


# 3. Clone if it doesn't exist, or navigate to it if it does
if not os.path.exists(PROJECT_PATH):
    # %cd /content/drive/MyDrive/Colab Notebooks/AICode/
    repo_url = f"https://{token}@github.com/{USERNAME}/{REPO_NAME}.git"
    # !git clone {repo_url}
    print("Repository cloned to Google Drive!")
else:
    print("Folder already exists in Drive.")

# 4. Move into the directory
# %cd {PROJECT_PATH}
# Out:
# Folder already exists in Drive.
# /content/drive/MyDrive/Colab Notebooks/AICode/AICode586

# %%
# !git pull origin main
# Out:
# From https://github.com/shashwatlko586/AICode586
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git add .

# %%
# !git commit -m "Updated files via Google Drive"
# Out:
# [main 48721e9] Updated files via Google Drive
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Colab_GH_Setup1.ipynb (98%)

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 790 bytes | 112.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/shashwatlko586/AICode586.git
#    43f419b..48721e9  main -> main

# %%
# !git branch --show-current

# %%
# !git ls-files
# Out:
# .gitignore
# AICode1.ipynb
# AICode586
# Basic/Area_of_a_Triangle
# Basic/Arithmetic_Check_with_Assignment_and_Logic.ipynb
# Basic/Average_Speed_Calculation.ipynb
# Basic/Currency_Split_into_Notes.ipynb
# Basic/Extract_Digits_and_Form_a_New_Number.ipynb
# Basic/Format_Time_from_Seconds.ipynb
# Basic/Solve_the_Expression.ipynb
# Basic/Strings_Check.ipynb
# Colab_GH_Setup1.ipynb
# Control Structures/Control_Structures_1.ipynb
# Control Structures/Control_Structures_2.ipynb
# Control Structures/Control_Structures_Main1.ipynb
# Control Structures/Control_Structures_Main2.ipynb
# DL/CNN/02_cnn_colab.ipynb
# DL/CNN/CNN_Assg_Waste_Segregation_Starter_V0.1.ipynb
# DL/CNN/CNN_Assg_Waste_Segregation_Starter_V0.2.ipynb
# DL/CNN/CNN_Assg_Waste_Segregation_Starter_V0.3.ipynb
# DL/CNN/CNN_Assg_Waste_Segregation_Starter_orig.ipynb
# DL/Encoder Decoder/Enoder-Decoder-LSTM.ipynb
# DL/Encoder Decoder/Simple-Encoder-Decoder.ipynb
# DL/FCFNN/01_fcfnn_colab.ipynb
# DL/RNN/03_rnn_lstm_colab.ipynb
# ...
